# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data=pd.read_csv("/kaggle/input/titanic/train.csv")

# %%
data.head()

# %%
data.tail()

# %%
data.info()

# %%
data.describe()

# %%
data.shape

# %%
pd.isnull(data).sum()

# %%
data[['Age','Cabin','Embarked']]

# %%
data.drop('Cabin',axis=1,inplace=True)

# %%
np.mean(data['Age'])

# %%
data['Age']=data['Age'].fillna(29.5)

# %%
pd.isnull(data).sum()

# %%
data=data.dropna()

# %%
pd.isnull(data).sum()

# %%
data.shape

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.info()

# %%
#data['Sex']=pd.Categorical(data['Sex'])
#data['Sex']=data.Sex.cat.codes

# %%
#data['Embarked']=pd.Categorical(data['Embarked'])
#data['Embarked']=data['Embarked'].cat.codes

# %%
data.head()

# %%
sns.pairplot(data)

# %%
sns.countplot("Survived",data=data)

# %%
sns.countplot("Pclass",data=data)

# %%
sns.countplot("Survived",data=data,hue='Pclass')

# %%
sns.countplot("Sex",data=data)

# %%
sns.countplot("Survived",data=data,hue='Sex')

# %%
sns.countplot("SibSp",data=data)

# %%
sns.countplot("Survived",data=data,hue='SibSp')

# %%
sns.countplot("Parch",data=data)

# %%
sns.countplot("Survived",data=data,hue='Parch')

# %%
sns.countplot("Embarked",data=data)

# %%
sns.countplot("Survived",data=data,hue='Embarked')

# %%
sns.countplot("Age",data=data)

# %%
plt.figure(figsize=(14,7))
sns.countplot("Age",data=data,hue='Survived')
plt.tight_layout()

# %%
data['Sex']=pd.Categorical(data['Sex'])
data['Sex']=data.Sex.cat.codes
data['Embarked']=pd.Categorical(data['Embarked'])
data['Embarked']=data.Embarked.cat.codes

# %%
data.corr()

# %%
sns.heatmap(data.corr(),annot=True,cmap='magma')

# %%
from sklearn.linear_model import  LogisticRegression

# %%
data.columns

# %%
x=data[['Pclass','Sex', 'Age', 'SibSp','Parch','Fare', 'Embarked']]

# %%
y=data['Survived']

# %%
lr=LogisticRegression()

# %%
lr.fit(x,y)

# %%
test=pd.read_csv("/kaggle/input/titanic/test.csv")

# %%
test.head()

# %%
test['Sex']=pd.Categorical(test['Sex'])
test['Sex']=test.Sex.cat.codes
test['Embarked']=pd.Categorical(test['Embarked'])
test['Embarked']=test.Embarked.cat.codes

# %%
testx=test[['Pclass','Sex', 'Age', 'SibSp','Parch','Fare', 'Embarked']]

# %%
testx.head()

# %%
testx.info()

# %%
testx.isnull().sum()

# %%
np.mean(testx['Age'])

# %%
m=testx['Age'].fillna(30.27)
m

# %%
testx['Age']=m

# %%
testx.isnull().sum()

# %%
testx['Fare'].value_counts()

# %%
testx[testx['Fare'].isnull()]

# %%
temp=testx[testx['Pclass']==3]
temp

# %%
temp[temp['Embarked']==2]['Fare'].value_counts().head()

# %%
testx['Fare']=testx['Fare'].fillna(8.05)

# %%
testx.isnull().sum()

# %%
pred=lr.predict(testx)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
gender=pd.read_csv('/kaggle/input/titanic/gender_submission.csv')
gender.head()

# %%
confusion_matrix(gender['Survived'],pred)

# %%
print(classification_report(gender['Survived'],pred))

# %%
submission={'PassengerId': gender['PassengerId'] , 'Survived': pred}

# %%
submission

# %%
submission=pd.DataFrame(submission)

# %%
submission.to_csv('sub_2titanic.csv',index=False)
